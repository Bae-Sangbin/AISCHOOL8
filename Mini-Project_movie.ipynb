# %%
import koreanize_matplotlib
# pandas, numpy, matplotlib.pyplot 불러오기
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from glob import glob

files = glob("C:/Users/tkdql/OneDrive/문서/KOBIS/KOBIS_기간별박스오피스_*.csv")
file_paths = sorted(files)
file_paths
# Out:
# ['C:/Users/tkdql/OneDrive/문서/KOBIS\\KOBIS_기간별박스오피스_2019.csv',
#  'C:/Users/tkdql/OneDrive/문서/KOBIS\\KOBIS_기간별박스오피스_2020.csv',
#  'C:/Users/tkdql/OneDrive/문서/KOBIS\\KOBIS_기간별박스오피스_2021.csv',
#  'C:/Users/tkdql/OneDrive/문서/KOBIS\\KOBIS_기간별박스오피스_2022.csv']

# %%
df_01 = pd.read_csv(file_paths[0], encoding = 'cp949')
df_01.shape
# Out:
# (4891, 18)

# %%
df_02 = pd.read_csv(file_paths[1], encoding = 'cp949')
df_02.shape
# Out:
# (4547, 18)

# %%
df_03 = pd.read_csv(file_paths[2], encoding = 'cp949')
df_03.shape
# Out:
# (4946, 18)

# %%
df_04 = pd.read_csv(file_paths[3], encoding = 'cp949')
df_04.shape
# Out:
# (4619, 18)

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
# %matplotlib inline

# %%
df = pd.concat([df_01, df_02,df_03, df_04])
df.shape
# Out:
# (19003, 18)

# %%
df.columns
# Out:
# Index(['순위', '영화명', '개봉일', '매출액', '매출액.1', '누적매출액', '관객수', '누적관객수', '스크린수',
#        '상영횟수', '대표국적', '국적', '제작사', '배급사', '등급', '장르', '감독', '배우'],
#       dtype='object')

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.dtypes
# Out:
# 순위       object
# 영화명      object
# 개봉일      object
# 매출액      object
# 매출액.1    object
# 누적매출액    object
# 관객수      object
# 누적관객수    object
# 스크린수     object
# 상영횟수     object
# 대표국적     object
# 국적       object
# 제작사      object
# 배급사      object
# 등급       object
# 장르       object
# 감독       object
# 배우       object
# dtype: object

# %%
#중복 제거하기
#shape를 통해서 데이터프레임의 크기를 확인
df = df.drop_duplicates()
df.shape
# Out:
# (18999, 18)

# %%
#데이터에 대한 정보를 볼 수 있습니다.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18999 entries, 0 to 4618
# Data columns (total 18 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   순위      18998 non-null  object
#  1   영화명     18990 non-null  object
#  2   개봉일     11966 non-null  object
#  3   매출액     18998 non-null  object
#  4   매출액.1   18995 non-null  object
#  5   누적매출액   18998 non-null  object
#  6   관객수     18998 non-null  object
#  7   누적관객수   18998 non-null  object
#  8   스크린수    18998 non-null  object
#  9   상영횟수    18998 non-null  object
#  10  대표국적    18861 non-null  object
#  11  국적      18861 non-null  object
#  12  제작사     5660 non-null   object
#  13  배급사     11725 non-null  object
#  14  등급      12761 non-null  object
#  15  장르      18779 non-null  object
#  16  감독      14909 non-null  object
#  17  배우      10157 non-null  object
# dtypes: object(18)
# memory usage: 2.8+ MB

# %%
df.isnull().sum().sum()
# Out:
# 47332

# %%
df.describe()
# Out:
#            순위      영화명         개봉일    매출액  매출액.1  누적매출액    관객수  누적관객수   스크린수  \
# count   18998    18990       11966  18998  18995  18998  18998  18998  18998
# unique   1893    14742        2523   5838     54   9426   3264   6764    699
# top      3538  라 트라비아타  2019-12-12  6,000   0.0%  6,000      1      1      1
# freq     1139        8          41   2528  18531   2518   3851   3784  14033
#
#          상영횟수   대표국적     국적       제작사          배급사       등급     장르       감독  \
# count   18998  18861  18861      5660        11725    12761  18779    14909
# unique   1783     72    504      1312          897       47    771     4570
# top         1     한국     한국  (주)영화사가을  (주)영진크리에이티브  청소년관람불가    드라마  버드맨 텟페이
# freq     7339   6666   6606       523         1041     5617   3451      133
#
#            배우
# count   10157
# unique   5988
# top       민도윤
# freq       37

# %%
df.columns.values
# Out:
# array(['순위', '영화명', '개봉일', '매출액', '매출액.1', '누적매출액', '관객수', '누적관객수',
#        '스크린수', '상영횟수', '대표국적', '국적', '제작사', '배급사', '등급', '장르', '감독', '배우'],
#       dtype=object)

# %%
df.values
# Out:
# array([[nan, nan, nan, ..., nan, nan, nan],
#        ['1', '극한직업', '2019-01-23', ..., '코미디', '이병헌',
#         '류승룡,이하늬,진선규,이동휘,공명,양현민,장진희,한준우,김명준,나철,정재광,정원창,김강현,김지영,오정세,이중옥,홍완표,고봉구,권지훈,권태호,김가빈,박재홍,서호철,김남우,박진아,송영규,안성봉,신하균,심철민,김병호,류제윤,김성우,이정수,김의성,김종수,고경진,고관형,이광기,지찬,구성환,이도용,천준호,정성훈,이하늬,이한종,임세운,한동희,임정묵,이범찬,이운산,김천,조주한,조현숙,이유진,정우영,신신애,윤설,정윤회,박도영,정재광,최광원,이두일,김윤배,최신득,이왕수,이육현,박정표,정인기,배정선,장지웅,임유란,엄지혜,오민준,태원석,장격수,편광진,하철,변봉식,홍승진,홍은진,허준석'],
#        ['2', '어벤져스: 엔드게임', '2019-04-24', ..., '액션,SF', '안소니 루소,조 루소',
#         '로버트 다우니 주니어,크리스 에반스,마크 러팔로,크리스 헴스워스,스칼렛 요한슨,제레미 레너,돈 치들,폴 러드,브리 라슨,카렌 길런,브래들리 쿠퍼,조슈 브롤린'],
#        ...,
#        ['4500', '휴일', nan, ..., '드라마', '이만희', '신성일,김성옥,김순철,김경란'],
#        ['4500', '흐루스탈료프, 나의 차!', nan, ..., '드라마', nan, nan],
#        ['합계', nan, nan, ..., nan, nan, nan]], dtype=object)

# %%
s = df["순위"]
s.head(5)
# Out:
# 0    NaN
# 1      1
# 2      2
# 3      3
# 4      4
# Name: 순위, dtype: object

# %%
temp = df[["영화명","개봉일"]]
temp.head(3)
# Out:
#           영화명         개봉일
# 0         NaN         NaN
# 1        극한직업  2019-01-23
# 2  어벤져스: 엔드게임  2019-04-24

# %%
#s.index
s.values
# Out:
# array([nan, '1', '2', ..., '4500', '4500', '합계'], dtype=object)

# %%
df.columns
# Out:
# Index(['순위', '영화명', '개봉일', '매출액', '매출액.1', '누적매출액', '관객수', '누적관객수', '스크린수',
#        '상영횟수', '대표국적', '국적', '제작사', '배급사', '등급', '장르', '감독', '배우'],
#       dtype='object')

# %%
df.columns = ['순위', '영화명', '개봉일', '매출액', '매출액점유율', '누적매출액', '관객수', '누적관객수', '스크린수',
       '상영횟수', '대표국적', '국적', '제작사', '배급사', '등급', '장르', '감독', '배우']

# %%
df.columns
# Out:
# Index(['순위', '영화명', '개봉일', '매출액', '매출액점유율', '누적매출액', '관객수', '누적관객수', '스크린수',
#        '상영횟수', '대표국적', '국적', '제작사', '배급사', '등급', '장르', '감독', '배우'],
#       dtype='object')

# %%
#인덱싱을 사용해서 value를 변경한다.

# %%
#데이터 타입 확인
df.dtypes
# Out:
# 순위        object
# 영화명       object
# 개봉일       object
# 매출액       object
# 매출액점유율    object
# 누적매출액     object
# 관객수       object
# 누적관객수     object
# 스크린수      object
# 상영횟수      object
# 대표국적      object
# 국적        object
# 제작사       object
# 배급사       object
# 등급        object
# 장르        object
# 감독        object
# 배우        object
# dtype: object

# %%
df["스크린수"].dtype
# Out:
# dtype('O')

# %%
df = df.dropna(how='all',subset=['순위','영화명','개봉일'])

# %%
df.isnull().sum().sum()
# Out:
# 47315

# %%
df.describe(include="object")
# Out:
#            순위      영화명         개봉일    매출액 매출액점유율  누적매출액    관객수  누적관객수   스크린수  \
# count   18998    18990       11966  18998  18994  18998  18998  18998  18998
# unique   1893    14742        2523   5838     53   9426   3264   6764    699
# top      3538  라 트라비아타  2019-12-12  6,000   0.0%  6,000      1      1      1
# freq     1139        8          41   2528  18531   2518   3851   3784  14033
#
#          상영횟수   대표국적     국적       제작사          배급사       등급     장르       감독  \
# count   18998  18861  18861      5660        11725    12761  18779    14909
# unique   1783     72    504      1312          897       47    771     4570
# top         1     한국     한국  (주)영화사가을  (주)영진크리에이티브  청소년관람불가    드라마  버드맨 텟페이
# freq     7339   6666   6606       523         1041     5617   3451      133
#
#            배우
# count   10157
# unique   5988
# top       민도윤
# freq       37

# %%
df['매출액'].astype('int64')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2864\862654640.py in <module>
# ----> 1 df['매출액'].astype('int64')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5910         else:
#    5911             # else, only a single dtype is given
# -> 5912             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913             return self._constructor(new_data).__finalize__(self, method="astype")
#    5914
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     417
#     418     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     420
#     421     def convert(
#
# ...

# %%
df[['매출액', '누적매출액','관객수','누적관객수','스크린수','상영횟수']] = df[['매출액', '누적매출액','관객수','누적관객수','스크린수','상영횟수']].replace('\,','',regex=True)

# %%
df[['매출액', '누적매출액','관객수','누적관객수','스크린수','상영횟수']] = df[['매출액', '누적매출액','관객수','누적관객수','스크린수','상영횟수']].replace('\,', '',regex=True)

# %%
df[['매출액', '누적매출액','관객수','누적관객수','스크린수','상영횟수']] = df[['매출액','누적매출액','관객수','누적관객수','스크린수','상영횟수']].astype('int64')

# %%
df.dtypes
# Out:
# 순위        object
# 영화명       object
# 개봉일       object
# 매출액        int64
# 매출액점유율    object
# 누적매출액      int64
# 관객수        int64
# 누적관객수      int64
# 스크린수       int64
# 상영횟수       int64
# 대표국적      object
# 국적        object
# 제작사       object
# 배급사       object
# 등급        object
# 장르        object
# 감독        object
# 배우        object
# dtype: object

# %%
df.value_counts()
# Out:
# 순위    영화명       개봉일         매출액           매출액점유율  누적매출액         관객수       누적관객수     스크린수  상영횟수    대표국적  국적  제작사                             배급사                 등급        장르          감독   배우
# 1     극한직업      2019-01-23  139651845516  7.3%    139651845516  16265618  16265618  2003  292584  한국    한국  (주)어바웃잇,영화사 해그림 주식회사,(주)씨제이이엔엠  (주)씨제이이엔엠           15세이상관람가  코미디         이병헌  류승룡,이하늬,진선규,이동휘,공명,양현민,장진희,한준우,김명준,나철,정재광,정원창,김강현,김지영,오정세,이중옥,홍완표,고봉구,권지훈,권태호,김가빈,박재홍,서호철,김남우,박진아,송영규,안성봉,신하균,심철민,김병호,류제윤,김성우,이정수,김의성,김종수,고경진,고관형,이광기,지찬,구성환,이도용,천준호,정성훈,이하늬,이한종,임세운,한동희,임정묵,이범찬,이운산,김천,조주한,조현숙,이유진,정우영,신신애,윤설,정윤회,박도영,정재광,최광원,이두일,김윤배,최신득,이왕수,이육현,박정표,정인기,배정선,장지웅,임유란,엄지혜,오민준,태원석,장격수,편광진,하철,변봉식,홍승진,홍은진,허준석    1
# ...

# %%
s1 = df['개봉일'].astype(np.datetime64)
s1
# Out:
# 1      2019-01-23
# 2      2019-04-24
# 3      2019-11-21
# 4      2019-05-23
# 5      2019-05-30
#           ...
# 4614   1998-12-19
# 4615   1994-07-30
# 4616          NaT
# 4617          NaT
# 4618          NaT
# Name: 개봉일, Length: 18998, dtype: datetime64[ns]

# %%
df.dtypes
# Out:
# 순위        object
# 영화명       object
# 개봉일       object
# 매출액        int64
# 매출액점유율    object
# 누적매출액      int64
# 관객수        int64
# 누적관객수      int64
# 스크린수       int64
# 상영횟수       int64
# 대표국적      object
# 국적        object
# 제작사       object
# 배급사       object
# 등급        object
# 장르        object
# 감독        object
# 배우        object
# dtype: object

# %%
df["개봉일"].astype(np.datetime64)
# Out:
# 1      2019-01-23
# 2      2019-04-24
# 3      2019-11-21
# 4      2019-05-23
# 5      2019-05-30
#           ...
# 4614   1998-12-19
# 4615   1994-07-30
# 4616          NaT
# 4617          NaT
# 4618          NaT
# Name: 개봉일, Length: 18998, dtype: datetime64[ns]

# %%
df["개봉일"] = pd.to_datetime(df["개봉일"], format = '%Y-%m-%d')

# %%
df.dtypes
# Out:
# 순위                object
# 영화명               object
# 개봉일       datetime64[ns]
# 매출액                int64
# 매출액점유율            object
# 누적매출액              int64
# 관객수                int64
# 누적관객수              int64
# 스크린수               int64
# 상영횟수               int64
# 대표국적              object
# 국적                object
# 제작사               object
# 배급사               object
# 등급                object
# 장르                object
# 감독                object
# 배우                object
# dtype: object

# %%
df["개봉일"].dt.year
# Out:
# 1       2019.0
# 2       2019.0
# 3       2019.0
# 4       2019.0
# 5       2019.0
#          ...
# 4614    1998.0
# 4615    1994.0
# 4616       NaN
# 4617       NaN
# 4618       NaN
# Name: 개봉일, Length: 18998, dtype: float64

# %%
df["개봉일"].dt.month
# Out:
# 1        1.0
# 2        4.0
# 3       11.0
# 4        5.0
# 5        5.0
#         ...
# 4614    12.0
# 4615     7.0
# 4616     NaN
# 4617     NaN
# 4618     NaN
# Name: 개봉일, Length: 18998, dtype: float64

# %%
df["개봉일"].dt.day
# Out:
# 1       23.0
# 2       24.0
# 3       21.0
# 4       23.0
# 5       30.0
#         ...
# 4614    19.0
# 4615    30.0
# 4616     NaN
# 4617     NaN
# 4618     NaN
# Name: 개봉일, Length: 18998, dtype: float64

# %%
df["개봉일"].dt.dayofweek
# Out:
# 1       2.0
# 2       2.0
# 3       3.0
# 4       3.0
# 5       3.0
#        ...
# 4614    5.0
# 4615    5.0
# 4616    NaN
# 4617    NaN
# 4618    NaN
# Name: 개봉일, Length: 18998, dtype: float64

# %%
df["연도"] = df["개봉일"].dt.year
df["월"] = df["개봉일"].dt.month
df["일"] = df["개봉일"].dt.day
df["요일"] = df["개봉일"].dt.dayofweek

# %%
df.head()
# Out:
#   순위         영화명        개봉일           매출액 매출액점유율         누적매출액       관객수  \
# 1  1        극한직업 2019-01-23  139651845516   7.3%  139651845516  16265618
# 2  2  어벤져스: 엔드게임 2019-04-24  122182694160   6.4%  122182694160  13934592
# 3  3      겨울왕국 2 2019-11-21  111596248720   5.8%  111596248720  13369064
# 4  4         알라딘 2019-05-23  106955138359   5.6%  106955138359  12552283
# 5  5         기생충 2019-05-30   85883963645   4.5%   85883963645  10085275
#
#       누적관객수  스크린수    상영횟수  ...                             제작사  \
# 1  16265618  2003  292584  ...  (주)어바웃잇,영화사 해그림 주식회사,(주)씨제이이엔엠
# 2  13934592  2835  242001  ...                             NaN
# 3  13369064  2648  282557  ...                             NaN
# 4  12552283  1409  266469  ...                             NaN
# 5  10085275  1948  192855  ...                      (주)바른손이앤에이
#
#                   배급사        등급           장르           감독  \
# 1           (주)씨제이이엔엠  15세이상관람가          코미디          이병헌
# ...

# %%
df.dtypes
# Out:
# 순위                object
# 영화명               object
# 개봉일       datetime64[ns]
# 매출액                int64
# 매출액점유율            object
# 누적매출액              int64
# 관객수                int64
# 누적관객수              int64
# 스크린수               int64
# 상영횟수               int64
# 대표국적              object
# 국적                object
# 제작사               object
# 배급사               object
# 등급                object
# 장르                object
# 감독                object
# 배우                object
# 연도               float64
# 월                float64
# 일                float64
# 요일               float64
# dtype: object

# %%
df['연도'] = df['연도'].str.contains('2019')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2864\766168946.py in <module>
# ----> 1 df['연도'] = df['연도'].str.contains('2019')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     180             # we're accessing the attribute of the class, i.e., Dataset.geo
#     181             return self._accessor
# --> 182         accessor_obj = self._accessor(obj)
#     183         # Replace the property with the accessor object. Inspired by:
#     184         # https://www.pydanny.com/cached-property.html
#
# ...

# %%
df
# Out:
#         순위            영화명        개봉일            매출액 매출액점유율          누적매출액  \
# 1        1           극한직업 2019-01-23   139651845516   7.3%   139651845516
# 2        2     어벤져스: 엔드게임 2019-04-24   122182694160   6.4%   122182694160
# 3        3         겨울왕국 2 2019-11-21   111596248720   5.8%   111596248720
# 4        4            알라딘 2019-05-23   106955138359   5.6%   106955138359
# 5        5            기생충 2019-05-30    85883963645   4.5%    85883963645
# ...    ...            ...        ...            ...    ...            ...
# 4614  4500    해가 서쪽에서 뜬다면 1998-12-19              0   0.0%              0
# 4615  4500    헐리우드 키드의 생애 1994-07-30              0   0.0%              0
# 4616  4500             휴일        NaT              0   0.0%              0
# 4617  4500  흐루스탈료프, 나의 차!        NaT              0   0.0%         224000
# 4618    합계            NaN        NaT  1160213540400    NaN  4626602376310
#
#             관객수      누적관객수    스크린수     상영횟수  ...  \
# ...

# %%
df.dtypes
# Out:
# 순위                object
# 영화명               object
# 개봉일       datetime64[ns]
# 매출액                int64
# 매출액점유율            object
# 누적매출액              int64
# 관객수                int64
# 누적관객수              int64
# 스크린수               int64
# 상영횟수               int64
# 대표국적              object
# 국적                object
# 제작사               object
# 배급사               object
# 등급                object
# 장르                object
# 감독                object
# 배우                object
# 연도               float64
# 월                float64
# 일                float64
# 요일               float64
# dtype: object

# %%
df.describe()
# Out:
#                 매출액         누적매출액           관객수         누적관객수           스크린수  \
# count  1.899800e+04  1.899800e+04  1.899800e+04  1.899800e+04   18998.000000
# mean   4.389005e+08  2.049559e+09  4.837761e+04  2.538841e+05      65.980156
# std    1.745317e+10  7.270498e+10  1.965693e+06  9.035948e+06    2287.379727
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00       1.000000
# 25%    1.025300e+04  3.800000e+04  3.000000e+00  8.000000e+00       1.000000
# 50%    2.240000e+05  7.970000e+05  4.700000e+01  1.430000e+02       1.000000
# 75%    1.167000e+06  1.613705e+07  2.360000e+02  3.683500e+03       2.000000
# max    1.913989e+12  6.139494e+12  2.266788e+08  7.797098e+08  180154.000000
#
#                상영횟수            연도             월            일            요일
# count  1.899800e+04  11966.000000  11966.000000  11966.00000  11966.000000
# mean   2.277635e+03   2015.953368      6.689621     15.64700      2.738927
# ...

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
df.describe()
# Out:
#                        매출액                누적매출액            관객수          누적관객수  \
# count            18,998.00            18,998.00      18,998.00      18,998.00
# mean        438,900,543.64     2,049,559,146.69      48,377.61     253,884.11
# std      17,453,166,551.42    72,704,975,400.45   1,965,692.91   9,035,947.98
# min                   0.00                 0.00           0.00           0.00
# 25%              10,253.00            38,000.00           3.00           8.00
# 50%             224,000.00           797,000.00          47.00         143.00
# 75%           1,167,000.00        16,137,050.00         236.00       3,683.50
# max   1,913,989,080,068.00 6,139,493,532,108.00 226,678,777.00 779,709,842.00
#
#             스크린수         상영횟수        연도         월         일        요일
# count  18,998.00    18,998.00 11,966.00 11,966.00 11,966.00 11,966.00
# mean       65.98     2,277.63  2,015.95      6.69     15.65      2.74
# ...

# %%
df['매출액'].count()
# Out:
# 18998

# %%
round(df["누적매출액"].mean(),2)
# Out:
# 2049559146.69

# %%
df['관객수'].var(), df['관객수'].std()
# Out:
# (3863948621840.0107, 1965692.9113775657)

# %%
Q1, Q2, Q3 = df['매출액'].quantile([0.25,0.5,0.75])

# %%
print(Q1,Q2,Q3,Q3-Q1)
# Out:
# 10253.0 224000.0 1167000.0 1156747.0

# %%
df.dtypes
# Out:
# 순위                object
# 영화명               object
# 개봉일       datetime64[ns]
# 매출액                int64
# 매출액점유율            object
# 누적매출액              int64
# 관객수                int64
# 누적관객수              int64
# 스크린수               int64
# 상영횟수               int64
# 대표국적              object
# 국적                object
# 제작사               object
# 배급사               object
# 등급                object
# 장르                object
# 감독                object
# 배우                object
# 연도               float64
# 월                float64
# 일                float64
# 요일               float64
# dtype: object

# %%
df.groupby('장르').mean()
# Out:
#                            매출액             누적매출액        관객수         누적관객수  \
# 장르
# SF              525,454,193.81  7,898,843,824.92  47,979.86    951,892.08
# SF,가족,드라마         1,581,000.00 66,717,700,300.00     176.00 10,917,400.00
# SF,가족,멜로/로맨스      8,993,026.67     18,019,053.33   1,257.33      2,519.00
# SF,공포(호러)        11,877,745.00     12,232,120.00   1,450.25      1,622.75
# SF,드라마           25,087,064.71  4,943,128,216.24   2,144.38    504,127.43
# ...                        ...               ...        ...           ...
# 판타지,액션,멜로/로맨스       201,500.00      1,320,500.00      35.00        247.00
# 판타지,액션,어드벤처      86,052,156.67  7,719,310,590.00   9,570.67  1,239,924.00
# 판타지,어드벤처      3,445,824,037.50  4,533,980,037.50 408,787.25    583,936.50
# 판타지,코미디       8,183,139,323.50  8,242,407,323.50 955,542.00    963,127.50
# 판타지,코미디,애니메이션    13,890,450.00     27,770,900.00   2,081.50      4,161.50
#
#                 스크린수      상영횟수       연도     월     일   요일
# 장르
# ...

# %%
df.groupby('장르')[['매출액']].mean()
# Out:
#                            매출액
# 장르
# SF              525,454,193.81
# SF,가족,드라마         1,581,000.00
# SF,가족,멜로/로맨스      8,993,026.67
# SF,공포(호러)        11,877,745.00
# SF,드라마           25,087,064.71
# ...                        ...
# 판타지,액션,멜로/로맨스       201,500.00
# 판타지,액션,어드벤처      86,052,156.67
# 판타지,어드벤처      3,445,824,037.50
# 판타지,코미디       8,183,139,323.50
# 판타지,코미디,애니메이션    13,890,450.00
#
# [771 rows x 1 columns]

# %%
df.groupby('장르')[['매출액','누적매출액']].sum()
# Out:
#                        매출액         누적매출액
# 장르
# SF             18916350977  284358377697
# SF,가족,드라마          1581000   66717700300
# SF,가족,멜로/로맨스      26979080      54057160
# SF,공포(호러)         95021960      97856960
# SF,드라마           526828359  103805692541
# ...                    ...           ...
# 판타지,액션,멜로/로맨스       201500       1320500
# 판타지,액션,어드벤처      258156470   23157931770
# 판타지,어드벤처       13783296150   18135920150
# 판타지,코미디        16366278647   16484814647
# 판타지,코미디,애니메이션     27780900      55541800
#
# [771 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18998 entries, 1 to 4618
# Data columns (total 22 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   순위      18998 non-null  object
#  1   영화명     18990 non-null  object
#  2   개봉일     11966 non-null  datetime64[ns]
#  3   매출액     18998 non-null  int64
#  4   매출액점유율  18994 non-null  object
#  5   누적매출액   18998 non-null  int64
#  6   관객수     18998 non-null  int64
#  7   누적관객수   18998 non-null  int64
#  8   스크린수    18998 non-null  int64
#  9   상영횟수    18998 non-null  int64
#  10  대표국적    18861 non-null  object
#  11  국적      18861 non-null  object
#  12  제작사     5660 non-null   object
#  13  배급사     11725 non-null  object
#  14  등급      12761 non-null  object
#  15  장르      18779 non-null  object
#  16  감독      14909 non-null  object
#  17  배우      10157 non-null  object
#  18  연도      11966 non-null  float64
#  19  월       11966 non-null  float64
#  20  일       11966 non-null  float64
# ...

# %%
#결측치 확인하기
df.isna()
# Out:
#          순위    영화명    개봉일    매출액  매출액점유율  누적매출액    관객수  누적관객수   스크린수   상영횟수  \
# 1     False  False  False  False   False  False  False  False  False  False
# 2     False  False  False  False   False  False  False  False  False  False
# 3     False  False  False  False   False  False  False  False  False  False
# 4     False  False  False  False   False  False  False  False  False  False
# 5     False  False  False  False   False  False  False  False  False  False
# ...     ...    ...    ...    ...     ...    ...    ...    ...    ...    ...
# 4614  False  False  False  False   False  False  False  False  False  False
# 4615  False  False  False  False   False  False  False  False  False  False
# 4616  False  False   True  False   False  False  False  False  False  False
# 4617  False  False   True  False   False  False  False  False  False  False
# 4618  False   True   True  False    True  False  False  False  False  False
#
# ...

# %%
#결측치의 갯수 컬럼별로 확인하기
df.isna().sum()
# Out:
# 순위            0
# 영화명           8
# 개봉일        7032
# 매출액           0
# 매출액점유율        4
# 누적매출액         0
# 관객수           0
# 누적관객수         0
# 스크린수          0
# 상영횟수          0
# 대표국적        137
# 국적          137
# 제작사       13338
# 배급사        7273
# 등급         6237
# 장르          219
# 감독         4089
# 배우         8841
# 연도         7032
# 월          7032
# 일          7032
# 요일         7032
# dtype: int64

# %%
pd.Series(df['제작사'].unique())
# Out:
# 0          (주)어바웃잇,영화사 해그림 주식회사,(주)씨제이이엔엠
# 1                                     NaN
# 2                              (주)바른손이앤에이
# 3                         (주)외유내강,(주)필름케이
# 4       주식회사 덱스터 픽쳐스,(주)퍼펙트스톰필름,(주)씨제이이엔엠
#                       ...
# 1308                              (주)둘리나라
# 1309                            ㈜영화사 백두대간
# 1310                                   국제
# 1311                            (주)선우프로덕션
# 1312                      (주)컬쳐플랫폼,매치컷(주)
# Length: 1313, dtype: object

# %%
#결측치 제외 갯수
df['대표국적'].value_counts()
# Out:
# 한국        6666
# 미국        3944
# 일본        3356
# 프랑스        954
# 기타         673
#           ...
# 카타르          1
# 마케도니아        1
# 이라크          1
# 유고슬라비아       1
# 세르비아         1
# Name: 대표국적, Length: 72, dtype: int64

# %%
df[df['제작사'].isna()]
# Out:
#         순위            영화명        개봉일            매출액 매출액점유율          누적매출액  \
# 2        2     어벤져스: 엔드게임 2019-04-24   122182694160   6.4%   122182694160
# 3        3         겨울왕국 2 2019-11-21   111596248720   5.8%   111596248720
# 4        4            알라딘 2019-05-23   106955138359   5.6%   106955138359
# 7        7  스파이더맨: 파 프롬 홈 2019-07-02    69010000100   3.6%    69010000100
# 9        9          캡틴 마블 2019-03-06    51507488723   2.7%    51507488723
# ...    ...            ...        ...            ...    ...            ...
# 4610  4500           파리대왕        NaT              0   0.0%              0
# 4611  4500      파리의 별빛 아래 2021-05-05              0   0.0%       14872350
# 4616  4500             휴일        NaT              0   0.0%              0
# 4617  4500  흐루스탈료프, 나의 차!        NaT              0   0.0%         224000
# 4618    합계            NaN        NaT  1160213540400    NaN  4626602376310
#
#             관객수      누적관객수    스크린수     상영횟수  ...  제작사  \
# ...

# %%
temp = df[['등급','장르']]
temp.describe()
# Out:
#              등급     장르
# count     12761  18779
# unique       47    771
# top     청소년관람불가    드라마
# freq       5617   3451

# %%
# 등급은 청소년관람불가가 가장 많으며 그 빈도수는 5617개이다.
# 등급의 종류는 47가지가 있다.
# 장르는 드라마가 가장 많으며 그 빈도수는 3451개이다.
# 장르의 종류수는 771가지가 있다.

# %% [markdown]
# df.mean(

# %%
df.mean()
# Out:
# C:\Users\tkdql\AppData\Local\Temp\ipykernel_2864\3698961737.py:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.mean()
# C:\Users\tkdql\AppData\Local\Temp\ipykernel_2864\3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# 매출액       438,900,543.64
# 누적매출액   2,049,559,146.69
# 관객수            48,377.61
# 누적관객수         253,884.11
# 스크린수               65.98
# 상영횟수            2,277.63
# 연도              2,015.95
# 월                   6.69
# 일                  15.65
# 요일                  2.74
# dtype: float64

# %%
#사분위수
iqr_info = df.quantile([0.25,0.5,0.75])
iqr_info.index = ['Q1','Q2','Q3']
iqr_info
# Out:
#             매출액         누적매출액    관객수    누적관객수  스크린수  상영횟수       연도     월  \
# Q1    10,253.00     38,000.00   3.00     8.00  1.00  1.00 2,018.00  4.00
# Q2   224,000.00    797,000.00  47.00   143.00  1.00  2.00 2,020.00  7.00
# Q3 1,167,000.00 16,137,050.00 236.00 3,683.50  2.00 15.00 2,021.00 10.00
#
#        일   요일
# Q1  8.00 2.00
# Q2 16.00 3.00
# Q3 23.00 3.00

# %%
df.min()
# Out:
# C:\Users\tkdql\AppData\Local\Temp\ipykernel_2864\3962516015.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.min()
# 순위                         1
# 개봉일      1946-10-21 00:00:00
# 매출액                        0
# 누적매출액                      0
# 관객수                        0
# 누적관객수                      0
# 스크린수                       1
# 상영횟수                       1
# 연도                  1,946.00
# 월                       1.00
# 일                       1.00
# 요일                      0.00
# dtype: object

# %%
df.max()
# Out:
# C:\Users\tkdql\AppData\Local\Temp\ipykernel_2864\1151452817.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.max()
# 순위                        합계
# 개봉일      2023-02-15 00:00:00
# 매출액            1913989080068
# 누적매출액          6139493532108
# 관객수                226678777
# 누적관객수              779709842
# 스크린수                  180154
# 상영횟수                 6871909
# 연도                  2,023.00
# 월                      12.00
# 일                      31.00
# 요일                      6.00
# dtype: object

# %%
df.apply('mean')
# Out:
# C:\Users\tkdql\AppData\Local\Temp\ipykernel_2864\1820816210.py:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.apply('mean')
# C:\Users\tkdql\AppData\Local\Temp\ipykernel_2864\1820816210.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.apply('mean')
# 매출액       438,900,543.64
# 누적매출액   2,049,559,146.69
# 관객수            48,377.61
# 누적관객수         253,884.11
# 스크린수               65.98
# 상영횟수            2,277.63
# 연도              2,015.95
# 월                   6.69
# 일                  15.65
# 요일                  2.74
# dtype: float64

# %%
df.apply(['min','max','mean'])
# Out:
# C:\Users\tkdql\AppData\Local\Temp\ipykernel_2864\1633805186.py:1: FutureWarning: ['순위', '영화명', '매출액점유율', '대표국적', '국적', '제작사', '배급사', '등급', '장르', '감독', '배우'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.apply(['min','max','mean'])
#        순위                           개봉일                  매출액  \
# min     1 1946-10-21 00:00:00.000000000                 0.00
# max    합계 2023-02-15 00:00:00.000000000 1,913,989,080,068.00
# mean  NaN 2016-06-19 11:10:54.053150464       438,900,543.64
#
#                     누적매출액            관객수          누적관객수       스크린수  \
# min                  0.00           0.00           0.00       1.00
# max  6,139,493,532,108.00 226,678,777.00 779,709,842.00 180,154.00
# mean     2,049,559,146.69      48,377.61     253,884.11      65.98
#
#              상영횟수       연도     월     일   요일
# min          1.00 1,946.00  1.00  1.00 0.00
# ...

# %%
plt.figure(figsize=(12,6))

# %%
genre = df['장르'].value_counts().sort_values(ascending = False).to_frame().head(10)

# %%
genre.head(3)
# Out:
#           장르
# 드라마     3451
# 기타      1958
# 멜로/로맨스  1387

# %%
grade = df['등급'].value_counts().sort_values(ascending = False).to_frame().head(10)

# %%
grade.head(3)
# Out:
#             등급
# 청소년관람불가   5617
# 15세이상관람가  2631
# 12세이상관람가  1978

# %%
plt.figure(figsize = (10,7))
plt.barh(genre.index, genre.장르)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize = (10,7))
plt.barh(grade.index, grade.등급)
plt.grid(True)
plt.show()

# %%
plt.subplot(1,4,1)
df['매출액'].plot(kind='box')
plt.subplot(1,4,2)
df['누적매출액'].plot(kind='box')
plt.subplot(1,4,3)
df['관객수'].plot(kind='box')
plt.subplot(1,4,4)
df['누적관객수'].plot(kind='box')
plt.tight_layout()
plt.show()

# %%
#type : series
df.set_index('장르')[['매출액','관객수']].sum(axis=1)
# Out:
# 장르
# 코미디             139668111134
# 액션,SF           122196628752
# 애니메이션           111609617784
# 어드벤처,가족,판타지     106967690642
# 드라마              85894048920
#                    ...
# 멜로/로맨스,드라마                 0
# 드라마                        0
# 드라마                        0
# 드라마                        0
# NaN            1160326345498
# Length: 18998, dtype: int64

# %%
df_1 = df.set_index(['장르', '등급']).sort_index()

# %%
df_1 = df_1.reset_index()
df_1
# Out:
#         장르        등급    순위        영화명        개봉일            매출액 매출액점유율  \
# 0       SF    12세관람가   715      공각기동대 2002-04-12        5413300   0.0%
# 1       SF    12세관람가  1040      공각기동대 2002-04-12        2438600   0.0%
# 2       SF  12세이상관람가   264       유랑지구 2019-04-18      147817410   0.0%
# 3       SF  12세이상관람가  2502    인 더 더스트 2019-10-04          50000   0.0%
# 4       SF  12세이상관람가  3453    마션 인베이션 2019-01-03           5000   0.0%
# ...    ...       ...   ...        ...        ...            ...    ...
# 18993  NaN       NaN  2465  모데라토 칸타빌레        NaT         169000   0.0%
# 18994  NaN       NaN  4500  막차로 온 손님들        NaT              0   0.0%
# 18995  NaN       NaN  4500         안개 1967-10-19              0   0.0%
# 18996  NaN       NaN  4500     제뉴인 러브        NaT              0   0.0%
# 18997  NaN       NaN    합계        NaN        NaT  1160213540400    NaN
#
#                누적매출액        관객수      누적관객수  ...  대표국적   국적  제작사  \
# ...

# %%
pd.set_option('display.max_columns',None)

# %%
sns.set_context("talk")
sns.set_palette("Set2")
sns.set_style("whitegrid")

# %%
df.isna().sum()
# Out:
# 순위            0
# 영화명           8
# 개봉일        7032
# 매출액           0
# 매출액점유율        4
# 누적매출액         0
# 관객수           0
# 누적관객수         0
# 스크린수          0
# 상영횟수          0
# 대표국적        137
# 국적          137
# 제작사       13338
# 배급사        7273
# 등급         6237
# 장르          219
# 감독         4089
# 배우         8841
# 연도         7032
# 월          7032
# 일          7032
# 요일         7032
# dtype: int64

# %%
df[['연도','월','일','요일']] = df[['연도','월','일','요일']].astype('int64')
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2864\3694033506.py in <module>
# ----> 1 df[['연도','월','일','요일']] = df[['연도','월','일','요일']].astype('int64')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5910         else:
#    5911             # else, only a single dtype is given
# -> 5912             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913             return self._constructor(new_data).__finalize__(self, method="astype")
#    5914
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     417
#     418     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     420
#     421     def convert(
#
# ...
